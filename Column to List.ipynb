# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('original.csv', sep=';')
df
# Out:
#      ano  population
# 0   1980   119011052
# 1   1981   121154159
# 2   1982   123774229
# 3   1983   126403352
# 4   1984   129025577
# 5   1985   131639272
# 6   1986   134228492
# 7   1987   136780739
# 8   1988   139280140
# 9   1989   141714953
# 10  1990   144090756
# 11  1991   146825475
# 12  1992   148684120
# 13  1993   151556521
# 14  1994   153726463
# 15  1995   155822296
# 16  1996   157070163
# 17  1997   159636297
# 18  1998   161790182
# 19  1999   163947436
# 20  2000   169799170
# 21  2001   172385776
# 22  2002   174632932
# 23  2003   176876251
# 24  2004   179108134
# 25  2005   184184074
# 26  2006   186770613
# 27  2007   189335191
# 28  2008   189612814
# 29  2009   191481045
# 30  2010   190755799
# 31  2011   192379287
# 32  2012   193976530
# 33  2013   201062789
# 34  2014   202799518
# 35  2015   204482459
# 36  2016   206114067

# %%
x = df['ano'].to_list()
x
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016]

# %%
y = df['population'].to_list()
y
# Out:
# [119011052,
#  121154159,
#  123774229,
#  126403352,
#  129025577,
#  131639272,
#  134228492,
#  136780739,
#  139280140,
#  141714953,
#  144090756,
#  146825475,
#  148684120,
#  151556521,
#  153726463,
#  155822296,
#  157070163,
#  159636297,
#  161790182,
#  163947436,
#  169799170,
#  172385776,
#  174632932,
#  176876251,
#  179108134,
#  184184074,
#  186770613,
#  189335191,
#  189612814,
#  191481045,
#  190755799,
#  192379287,
#  193976530,
#  201062789,
#  202799518,
#  204482459,
#  206114067]

# %%
plt.plot(x,y)
plt.show()
